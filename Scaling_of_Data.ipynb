# %% [markdown]
# <a href="https://colab.research.google.com/github/JamshedAli18/Data-Preprocessing-Scikit-learn/blob/main/Scaling_of_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
x = df.drop('median_house_value',axis=1)
y = df['median_house_value']

# %%
import matplotlib.pyplot as plt
plt.scatter(df.longitude ,df.population)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
import numpy as np

np.round(X_test.describe(),1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count      900.0     900.0               900.0        900.0           900.0
# mean      -119.7      35.7                28.9       2633.4           538.3
# std          2.0       2.1                12.8       2059.8           402.5
# min       -124.2      32.6                 1.0          6.0             2.0
# 25%       -121.9      33.9                18.0       1402.5           295.5
# 50%       -118.6      34.3                29.0       2177.0           451.5
# 75%       -118.1      37.7                38.0       3303.5           672.2
# max       -114.5      41.3                52.0      20354.0          4585.0
#
#        population  households  median_income
# count       900.0       900.0          900.0
# mean       1433.7       503.1            3.8
# std        1067.6       365.1            1.9
# min           5.0         2.0            0.5
# 25%         775.0       275.0            2.6
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scalar.transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[-1.22815316,  1.29636548,  1.30162921, ..., -0.54298029,
#         -0.4522268 , -0.73102976],
#        [ 0.62561586, -0.88702898, -0.22632035, ..., -0.01732143,
#         -0.06912289,  0.17969284],
#        [-0.87553405,  1.17847161, -1.19134112, ..., -0.59623653,
#         -0.55621214, -0.02103276],
#        ...,
#        [-0.71433675,  1.56044775, -1.7542699 , ...,  0.58033198,
#          0.5411069 ,  0.55174841],
#        [-0.25593191,  0.64559132,  0.49744523, ..., -0.17906262,
#         -0.23331028, -1.30673964],
#        [-0.99643203,  1.41425935, -0.30673874, ...,  1.78155616,
#          1.61106139, -0.57336714]])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns = X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns = X_test.columns)

# %%
X_test_scaled.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.228153  1.296365            1.301629    -0.367673       -0.444909
# 1   0.625616 -0.887029           -0.226320     0.057352       -0.043596
# 2  -0.875534  1.178472           -1.191341    -0.471082       -0.544644
# 3   0.953048 -0.726693            0.819119    -0.537592       -0.444909
# 4   0.620578 -0.769135            1.864558    -0.367673       -0.490027
#
#    population  households  median_income
# 0   -0.542980   -0.452227      -0.731030
# 1   -0.017321   -0.069123       0.179693
# 2   -0.596237   -0.556212      -0.021033
# 3    0.098067   -0.405707      -1.196316
# 4   -0.586374   -0.561685      -0.163998

# %%
np.round(X_test_scaled.describe(),1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count      900.0     900.0               900.0        900.0           900.0
# mean        -0.1       0.1                 0.0          0.0             0.0
# std          1.0       1.0                 1.0          0.9             1.0
# min         -2.3      -1.4                -2.2         -1.2            -1.2
# 25%         -1.2      -0.8                -0.9         -0.5            -0.5
# 50%          0.5      -0.6                 0.0         -0.2            -0.2
# 75%          0.7       1.0                 0.7          0.3             0.3
# max          2.5       2.7                 1.9          8.1             9.6
#
#        population  households  median_income
# count       900.0       900.0          900.0
# mean          0.0         0.1           -0.0
# std           1.1         1.0            1.0
# min          -1.4        -1.3           -1.8
# 25%          -0.6        -0.6           -0.7
# ...

# %%
plt.scatter(X_train_scaled.longitude ,X_train_scaled.population)

# %%
plt.scatter(df.longitude ,df.population,color='red')

# %%
plt.scatter(X_train_scaled.longitude ,X_train_scaled.population)
plt.scatter(df.longitude ,df.population,color='red')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train_scaled,y_train)
# Out:
# 0.6208422082893523

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.6208422082893522
