# %% [markdown]
# <a href="https://colab.research.google.com/github/JamshedAli18/Data-Preprocessing-Scikit-learn/blob/main/Handling_Missing_Values_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 35, None, 40],
    'Salary': [50000, 60000, None, 80000, 90000],
    'Department': ['HR', 'IT', 'IT', 'HR', 'IT']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob  30.0  60000.0         IT
# 2  Charlie  35.0      NaN         IT
# 3    David   NaN  80000.0         HR
# 4      Eve  40.0  90000.0         IT

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
df['Age'] = imputer.fit_transform(df[['Age']])
df['Salary'] = imputer.fit_transform(df[['Salary']])

# %%
df
# Out:
#       Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob  30.0  60000.0         IT
# 2  Charlie  35.0  70000.0         IT
# 3    David  32.5  80000.0         HR
# 4      Eve  40.0  90000.0         IT
